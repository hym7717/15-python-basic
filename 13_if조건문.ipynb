# %%
x = 10

if x == 10:
    pass

print('10입니다.')
# Out:
# 10입니다.

# %%
x = 10

if x == 10:
    print('x에 들어있는 숫자는')
    print('10입니다.')
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
x = 10

if x == 10:
    print('x에 들어있는 숫자는')
print('10입니다.')
# Out:
# x에 들어있는 숫자는
# 10입니다.

# %%
x = 5

if x == 10:
    print('x에 들어있는 숫자는')
print('10입니다.')
# Out:
# 10입니다.

# %%
# 중첩  if조건문 사용하기
# x = 15
# x = 10
x = 20

if x >= 10:
    print('10 이상입니다.')

    if x == 10:
        print("10 입니다.")
    
    if x == 20:
        print('20 입니다.')
# Out:
# 10 이상입니다.
# 20 입니다.

# %%
x = int(input('숫자를 입력하세요.'))

if x == 10:
    print('10입니다.')

if x == 20:
    print('20입니다.')
# Out:
# 10입니다.

# %%
x = 5
if x != 10:
    print('ok')
# Out:
# ok

# %%
c = int(input('쿠폰').split()[1])
money = int(input('돈'))

if money <= 27000:
    print(money - c)

if money > 27000:
    print(money - c)
