# %%
hello = "Hello world"
print(hello)
# Out:
# Hello world

# %%
hello = "안농하세여~"
print(hello)
# Out:
# 안농하세여~

# %%
hello = '''Hello World!'''
print(hello)
# Out:
# Hello World!

# %%
python = """Python Programming"""
print(python)
# Out:
# Python Programming

# %%
# 여러줄로 된 문자열 사용하기
hello = '''Hello, World!
안농하세염!!
저는 파이떤이에염 ><'''

print(hello)
# Out:
# Hello, World!
# 안농하세염!!
# 저는 파이떤이에염 ><

# %%
# 문자열 안에 작은따옴표나 큰따옴표 포함하기
s = "Python isn't difficult"
print(s)
# Out:
# Python isn't difficult

# %%
s = 'He said "Pythons is easy"'
print(s)
# Out:
# He said "Pythons is easy"

# %%
s = "He \'sa\nid \"Pythons \tis \\easy\""
print(s)
# Out:
# He 'sa
# id "Pythons 	is \easy"

# %%
s = ''''hello', Python'''
print(s)
# Out:
# 'hello', Python

# %%
s = 'Python is a programming language hat lets you work quickly\nand\nintegrate systems more effectively.'
print(s)
# Out:
# Python is a programming language hat lets you work quickly
# and
# integrate systems more effectively.

# %%
s = ''''Python' is a "programming language"
that lets you work quickly
and
integrate systems more effectively'''
print(s)
# Out:
# 'Python' is a "programming language"
# that lets you work quickly
# and
# integrate systems more effectively
