# %%
def ten_div(x):
    return 10/x


print(ten_div(2))
print(ten_div(0))
# Out:
# 5.0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2     return 10/x
#       3
#       4
#       5 print(ten_div(2))
# ----> 6 print(ten_div(0))
#
# Cell In[3], line 2, in ten_div(x)
#       1 def ten_div(x):
# ----> 2     return 10/x
#
# ZeroDivisionError: division by zero

# %%
# try except

# try:
    # 실행할코드
# except:
    # 예외가 발생했을 때 처리하는 코드

try:
    x = int(input('숫자를 입력하세요: '))
    y = 10 / x
    print(y)
except:
    print('예외가 발생했습니다.')
# Out:
# 2.0

# %%
# 특정 예외만 처리하기
# try:
    # 실행할코드
# except 예외이름:
    # 예외가 발생했을 때 처리하는 코드


y = [10, 20, 30]

try:
    index, x = map(int, input('숫자').split())
    print(y[index] / x)    
except ZeroDivisionError:
    print('숫자를 0으로 나눌 수 없습니다.')
except IndexError:
    print('잘못된 인덱스입니다.')
# Out:
# 숫자를 0으로 나눌 수 없습니다.

# %%
# 예외의 에러메세지 받아오기

# try:
    # 실행할코드
# except 예외이름 as e:
    # 예외가 발생했을 때 처리하는 코드

y = [10, 20, 30]

try:
    index, x = map(int, input('숫자').split())
    print(y[index] / x)    
except ZeroDivisionError as e:
    print('숫자를 0으로 나눌 수 없습니다.',e)
except IndexError as e:
    print('잘못된 인덱스입니다.',e)
# Out:
# 잘못된 인덱스입니다. list index out of range

# %%
# else 와 finally 사용하기

# try:
    # 실행할코드
# except 예외이름:
    # 예외가 발생했을 때 처리하는 코드
# else:
    # 예외가 발생하지 않았을 때 코드

try:
    x = int(input('숫자를 입력하세요: '))
    y = 10 / x
except:
    print('예외가 발생했습니다.')
else:
    print(y)
# Out:
# 예외가 발생했습니다.

# %%
# try:
    # 실행할코드
# except 예외이름:
    # 예외가 발생했을 때 처리하는 코드
# else:
    # 예외가 발생하지 않았을 때 코드
# finally:
    # 예외 발생 여부와 상관없이 항상 실행할 코드

try:
    x = int(input('숫자를 입력하세요: '))
    y = 10 / x
except:
    print('예외가 발생했습니다.')
else:
    print(y)
finally:
    print('코드 실행이 끝났습니다.')
# Out:
# 예외가 발생했습니다.
# 코드 실행이 끝났습니다.

# %%
# 예외발생시키기
# raise 예외('에러메세지')

try:
    x = int(input('3의 배수를 입력: '))
    if x % 3 != 0:
        raise Exception('3의 배수가 아닙니다.')
except Exception as e:
    print('예외가 발생했습니다.', e)
# Out:
# 예외가 발생했습니다. 3의 배수가 아닙니다.

# %%
# raise의 처리과정

def three_multiple():
    x = int(input('3의 배수를 입력하세요: '))

    if x % 3 != 0:
        raise Exception('3의 배수가 아닙니다.')
    print(x)

try:
    three_multiple()
except Exception as e:
    print('예외가 발생했습니다.', e)

# %%
# 현재 예외를 다시 발생시키기
def three_multiple():
    try:
        x = int(input('3의 배수를 입력하세요: '))

        if x % 3 != 0:
            raise Exception('3의 배수가 아닙니다.')
        print(x)
    except Exception as e:
        print('three_multiple 함수에서 에러가 발생했습니다.', e)
        raise


try:
    three_multiple()
except Exception as e:
    print('예외가 발생했습니다.', e)
# Out:
# three_multiple 함수에서 에러가 발생했습니다. 3의 배수가 아닙니다.
# 예외가 발생했습니다. 3의 배수가 아닙니다.

# %%
# 예외 만들기

# class 예외이름(Exception):
    # def __init__(self):
        # super().__init__('에러메시지')

class NotThreeMultipleError(Exception):
    def __init__(self):
        super().__init__('3의 배수가 아닙니다.')

def three_multiple():
    try:
        x = int(input('3의 배수를 입력하세요: '))
        if x % 3 != 0:
            raise NotThreeMultipleError
        print(x)
    except Exception as e:
        print('예외가 발생했습니다.', e)


three_multiple()
# Out:
# 예외가 발생했습니다. 3의 배수가 아닙니다.
