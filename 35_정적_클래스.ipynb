# %%
# 클래스 속성 사용하기

# class 클래스이름:
    # 속성 = 값

class Person:
    bag = []

    def put_bag(self, stuff):
        Person.bag.append(stuff)


james =Person()
james.put_bag('책')

maria =Person()
maria.put_bag('열쇠')


print(james.bag)
print(maria.bag)
# Out:
# ['책', '열쇠']
# ['책', '열쇠']

# %%
print(Person.bag)
# Out:
# ['책', '열쇠']

# %%
# 인스턴스 속성 사용하기

class Person:
    # bag = []

    def __init__(self):
        self.bag = []

    def put_bag(self, stuff):
        self.bag.append(stuff)


james =Person()
james.put_bag('책')

maria =Person()
maria.put_bag('열쇠')


print(james.bag)
print(maria.bag)
# Out:
# ['책']
# ['열쇠']

# %%
# 비공개 클래스 속성 사용하기
# class 클래스이름:
    # __속성 = 값

class Knight:
    __item_limit = 10

    def print_item_limit(self):
        print(Knight.__item_limit)

x = Knight()
x.print_item_limit()

print(Knight.__item_limit())
# Out:
# 10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 14
#      10
#      11 x = Knight()
#      12 x.print_item_limit()
#      13
# ---> 14 print(Knight.__item_limit())
#
# AttributeError: type object 'Knight' has no attribute '__item_limit'

# %%
# 정적 매서드 사용하기

# class 클래스이름:
    # @staticmethod
    # def 매서드(매개변수):
        # 코드

class Calc:
    @staticmethod
    def add(a, b):
        return a + b
    
    @staticmethod
    def mul(a, b):
        return a * b
    
print(Calc.add(10, 20))
print(Calc.mul(10, 20))
# Out:
# 30
# 200

# %%
# 클래스 매서드 사용하기

# class 클래스이름:
    # @classmethod
    # def 메서드(cls, 매개변수1, 매개변수2):
        # 코드

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def print_count(cls):
        print(f'{cls.count}명 생성 되었습니다.')

james = Person()
maria = Person()

Person.print_count()
# Out:
# 2명 생성 되었습니다.

# %%
# 매서드 오버라이딩
class Person:
    def greeting(self):
        print('안녕하세요')


class Student(Person):
    def greeting(self):
        print('안녕하세요 저는 파이썬 학생입니다.')


james = Student()
james.greeting()
# Out:
# 안녕하세요 저는 파이썬 학생입니다.

# %%
class Person:
    def greeting(self):
        print('안녕하세요')


class Student(Person):
    def greeting(self):
        super().greeting()
        print('안녕하세요 저는 파이썬 학생입니다.')


james = Student()
james.greeting()
# Out:
# 안녕하세요
# 안녕하세요 저는 파이썬 학생입니다.

# %%
# Out:
# 안녕하세요
# 학생 관리
# 공부하기

# %%
# Out:
# 안녕하세요 B입니다.

# %%
# Out:
# [__main__.D, __main__.B, __main__.C, __main__.A, object]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 26
#      22 class Student(StudentBase):
#      23     def study(self):
#      24         print('공부하기')
#      25
# ---> 26 james = Student()
#      27 james.study()
#
# TypeError: Can't instantiate abstract class Student without an implementation for abstract method 'go_to_schoool'

# %%
# Out:
# 공부하기

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 james = StudentBase()
#
# TypeError: Can't instantiate abstract class StudentBase without an implementation for abstract methods 'go_to_schoool', 'study'
